# %%
import pandas as pd
import os

dir_path = "../Scrapy/scrapeTest/scrapeTest/spiders/output/"
data = pd.read_csv(os.path.join(dir_path, os.listdir(dir_path)[-1])) # 最新のファイルのみDBに格納。TODO:古いファイル消したほうがいいか？
data
# Out:
#                      name     price    area           address  \
# 0              インペリアルお茶の水    1380万円   14.84     東京都千代田区神田小川町３
# 1             ライオンズプラザ上野毛    1480万円   19.68  東京都世田谷区上野毛１-23-5
# 2                 ハイライフ大森    1480万円   22.61        東京都品川区南大井３
# 3              東建西が丘マンション    1580万円   39.24         東京都北区西が丘１
# 4                 サンライズ蓮根    1599万円   38.25  東京都板橋区東坂下２-10-16
# ...                   ...       ...     ...               ...
# 22834  ＴＨＥ　ＲＯＰＰＯＮＧＩ　ＴＯＫＹＯ  1億5500万円   48.30         東京都港区六本木３
# 22835         ディアナコート学芸大学  1億6800万円   92.14        東京都目黒区中央町２
# 22836          ザ・パークハウス大崎  1億7400万円   88.54         東京都品川区大崎２
# 22837             フォルム六番町  1億9900万円   81.90        東京都千代田区六番町
# 22838     シティタワーズ豊洲ザ・シンボル  2億8000万円  128.63         東京都江東区豊洲３
#
#                station_info      layout built_year_month             time  \
# 0      東京メトロ千代田線「新御茶ノ水」徒歩4分       ワンルーム          1980年8月  20231019_160413
# 1           東急大井町線「上野毛」徒歩3分       ワンルーム          1994年2月  20231019_160413
# 2           ＪＲ京浜東北線「大森」徒歩8分       ワンルーム         1973年12月  20231019_160413
# 3           都営三田線「本蓮沼」徒歩12分         2DK          1972年5月  20231019_160413
# 4            都営三田線「蓮根」徒歩10分        1LDK         1975年10月  20231019_160413
# ...                     ...         ...              ...              ...
# 22834    東京メトロ日比谷線「六本木」徒歩3分        1LDK         2011年11月  20231019_160413
# 22835       東急東横線「学芸大学」徒歩6分        3LDK          1999年5月  20231019_160413
# 22836         ＪＲ山手線「大崎」徒歩5分        3LDK          2012年4月  20231019_160413
# 22837        ＪＲ総武線「四ツ谷」徒歩5分  2LDK+S（納戸）          2000年2月  20231019_160413
# 22838     東京メトロ有楽町線「豊洲」徒歩6分        2LDK         2009年12月  20231019_160413
#
#                                                      url
# 0      https://suumo.jp/chukomansion/__JJ_JJ010FJ100_...
# 1      https://suumo.jp/chukomansion/__JJ_JJ010FJ100_...
# 2      https://suumo.jp/chukomansion/__JJ_JJ010FJ100_...
# 3      https://suumo.jp/chukomansion/__JJ_JJ010FJ100_...
# 4      https://suumo.jp/chukomansion/__JJ_JJ010FJ100_...
# ...                                                  ...
# 22834  https://suumo.jp/chukomansion/__JJ_JJ010FJ100_...
# 22835  https://suumo.jp/chukomansion/__JJ_JJ010FJ100_...
# 22836  https://suumo.jp/chukomansion/__JJ_JJ010FJ100_...
# 22837  https://suumo.jp/chukomansion/__JJ_JJ010FJ100_...
# 22838  https://suumo.jp/chukomansion/__JJ_JJ010FJ100_...
#
# [22839 rows x 9 columns]

# %%
from sqlalchemy import create_engine

# PostgreSQLへの接続設定
# DATABASE_URL = "DM名://ユーザ名:パスワード@アドレス:ポート/DB名"
DATABASE_URL = "postgresql://postgres:postgres@127.0.0.1:5432/suumo"
engine = create_engine(DATABASE_URL)

# DataFrameをPostgreSQLに保存
data.to_sql('data', engine, if_exists='append', index=False)
# Out:
# 839

# %%
# !jupyter nbconvert --to python Untitled.ipynb
# Out:
# [NbConvertApp] Converting notebook Untitled.ipynb to python
# [NbConvertApp] Writing 651 bytes to Untitled.py
